# %%
import pandas as pd
import numpy as np
from factor_analyzer import FactorAnalyzer
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
file_path = "/Users/stageacomeback/Desktop/4th Shrinked R4V1.csv"
data = pd.read_csv(file_path)

# %%
# Normalize the data using StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
# Perform Factor Analysis
fa = FactorAnalyzer(n_factors=5, rotation="promax", method="principal")
fa.fit(scaled_data)
# Out:
# /Users/stageacomeback/anaconda3/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# FactorAnalyzer(method='principal', n_factors=5, rotation_kwargs={})

# %%
# Get the factor loadings (Pattern Matrix)
pattern_matrix = fa.loadings_

# %%
# Set absolute values below 0.6 to 0 for clarity
pattern_matrix[np.abs(pattern_matrix) < 0.6] = 0

# %%
# Convert to DataFrame for better readability
columns = ["Component 1", "Component 2", "Component 3", "Component 4", "Component 5"]
pattern_df = pd.DataFrame(pattern_matrix, columns=columns, index=data.columns)

# %%
# Display the Pattern Matrix
print("Pattern Matrix (Absolute Values < 0.6 suppressed):")
print(pattern_df)
# Out:
# Pattern Matrix (Absolute Values < 0.6 suppressed):
#        Component 1  Component 2  Component 3  Component 4  Component 5
# R4MT3     0.713597     0.000000     0.000000     0.000000     0.000000
# R4MT4     0.866282     0.000000     0.000000     0.000000     0.000000
# R4MT5     0.856113     0.000000     0.000000     0.000000     0.000000
# R4RA3     0.000000     0.000000     0.000000     0.000000     0.000000
# R4RA4     0.000000     0.790529     0.000000     0.000000     0.000000
# R4RA5     0.000000     0.793249     0.000000     0.000000     0.000000
# R4VA3     0.000000     0.000000     0.647279     0.000000     0.000000
# R4VA4     0.000000     0.000000     0.836643     0.000000     0.000000
# R4VA5     0.000000     0.000000     0.000000     0.000000     0.000000
# R4IA3     0.000000     0.000000     0.750517     0.000000     0.000000
# R4IA4     0.000000     0.000000     0.000000     0.904522     0.000000
# R4IA5     0.000000     0.000000     0.729351     0.000000     0.000000
# R4AA1     0.000000     0.000000     0.000000     0.000000     0.000000
# R4AA2     0.000000     0.000000     0.000000     0.000000     0.643112
# R4AA3     0.000000     0.000000     0.000000     0.000000     0.000000
